# %% [markdown]
# # Упражнение 2. Выполнить парсинг веб-страниц с помощью Beautiful Soup и Pandas открытых источников данных, согласно варианта:

# %% [markdown]
# 11.   Анализ российских облигаций — https://www.dohod.ru/analytic/bonds

# %%
from bs4 import BeautifulSoup as bso
import requests as reqs
import pandas as pd

# %%
# Отправление запроса на получение данных и присваивание ответ переменной.
source = reqs.get("https://www.dohod.ru/analytic/bonds")

# %%
print(f"Content type: \n\t {source.headers['content-type']}")
# Out:
# Content type:
# 	 text/html; charset=UTF-8

# %%
print(source)
# Out:
# <Response [200]>

# %%
mysoup = bso(source.text, 'html.parser')

# %%
print(mysoup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ru">
#  <head>
#   <title>
#    Анализ облигаций
#   </title>
#   <meta content="Выбор и поиск облигаций для покупки по параметрам доходности, надежности и качества. Если вы ищете какие облигации купить, просто используйте наши готовые подборки для самых различных инвестиционных целей. " name="description"/>
#   <meta content="" name="keywords"/>
#   <base href="https://www.dohod.ru/"/>
#   <meta charset="utf-8">
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#    <meta content="telephone=no" name="format-detection"/>
#    <meta content="#da532c" name="msapplication-TileColor"/>
#    <meta content="#ffffff" name="theme-color"/>
#    <meta content="Доход.ру - Анализ облигаций" property="og:title">
# ...

# %%
print(mysoup.title)
# Out:
# <title>
#     Анализ облигаций  </title>
